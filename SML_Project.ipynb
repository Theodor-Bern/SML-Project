# %% [markdown]
# <a href="https://colab.research.google.com/github/Theodor-Bern/SML-Project/blob/main/SML_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Fett!")
# Out:
# Fett!
